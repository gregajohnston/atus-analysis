# %% [markdown]
# # Results Notebook

# %% [markdown]
# ### Importing data plots

# %%
from atus_analysis import (draw_plot_one, draw_plot_two,
                           draw_plot_three, draw_plot_four)
# %matplotlib inline

# %% [markdown]
# ### Effects of family size on the decision to work
# For each number of children in a family, display the average hours of work for men and women.
# Both lines have downward concavity, but the women's curve much more quickly loses hours of work.
# The spikes in both graphs is probably due to the relatively small number of families that have 6+ children.

# %%
draw_plot_one()

# %% [markdown]
# ### Occupation types based on employee age
# For different employment structures, display the average age of workers.
# Notice that volunteer workers (those that don't receive pay) tend to be much younger than the rest, while self-employed workers tend to be slightly older)

# %%
draw_plot_two()

# %% [markdown]
# ### Art entertainment choices by age groups
# For each 5 year age bracket, observerations of the total number of minutes spent on serveral different categories of art/entertainment, excluding sports. Entertainment consumption for all varieties listed tends to peak around early adulthood (30-40), except for gambling, which is skewed toward late adulthood and early retirment.

# %%
draw_plot_three()

# %% [markdown]
# ## Markdown Chart Four
# Comparison of the minutes spent watching various sports versus playing those sports. This graph sums each respondents time spent watching sports and time spent playing sports and draws a point at the intersect. Interestingly, most people either spend time watching or playing, but relatvely few people actually do both.

# %%
draw_plot_four()
